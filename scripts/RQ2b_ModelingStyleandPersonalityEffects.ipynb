# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.miscmodels.ordinal_model import OrderedModel
import re

def normalize_expl_type(x: str) -> str:
    if pd.isna(x):
        return ""
    s = re.sub(r"[^a-z]", "", str(x).strip().lower())
    mapping = {
        "feature": "featurebased", "featurebased": "featurebased", "features": "featurebased",
        "openness": "openness", "open": "openness", "o": "openness",
        "conscientiousness": "conscientiousness", "cons": "conscientiousness", "c": "conscientiousness",
        "extraversion": "extroversion", "extroversion": "extroversion", "extra": "extroversion", "e": "extroversion",
        "agreeableness": "agreeableness", "agree": "agreeableness", "a": "agreeableness",
        "neuroticism": "neuroticism", "neuro": "neuroticism", "n": "neuroticism",
    }
    return mapping.get(s, s)

def to_ordered_numeric(s: pd.Series, mapping: dict | None = None) -> pd.Series:
    """Coerce to ordered numeric. If already numeric, keep it; else code by categorical order or provided mapping."""
    if mapping is not None:
        return s.astype(str).str.strip().str.lower().map(mapping)
    sn = pd.to_numeric(s, errors="coerce")
    if sn.notna().any():
        return sn
    cats = pd.Categorical(s.astype(str))
    return pd.Series(cats.codes, index=s.index).replace(-1, np.nan)

def _format_ols_table(res, decimals=3):
    ci = res.conf_int()
    tbl = pd.DataFrame({
        "coef": res.params,
        "t": res.tvalues,
        "p>|t|": res.pvalues,
        "ci_low": ci[0],
        "ci_high": ci[1],
    })
    return tbl.round(decimals)

def fit_ols(formula: str, data: pd.DataFrame, cluster_col="user_id"):
    model = smf.ols(formula=formula, data=data)
    return model.fit(cov_type="cluster", cov_kwds={"groups": data[cluster_col]})


df = analysis_df.copy()
df["explanation_type_norm"] = df["explanation type"].apply(normalize_expl_type)


styles = ["openness","conscientiousness","extroversion","agreeableness","neuroticism","featurebased"]
traits_ord = ["openness","conscientiousness","extroversion","agreeableness","neuroticism"]


for target_prefix in ["quality", "taste", "listen"]:
    ycol = f"y_{target_prefix}"
    df[ycol] = np.nan
    for st in styles:
        src_col = f"{target_prefix}_{st}"
        if src_col in df.columns:
            mask = df["explanation_type_norm"] == st
            df.loc[mask, ycol] = df.loc[mask, src_col]

model_df = df.dropna(subset=["y_quality","y_taste","y_listen"]).copy()


for t in traits_ord:
    if t in model_df.columns:
        model_df[t] = pd.to_numeric(model_df[t], errors="coerce")


model_df["age_num"] = to_ordered_numeric(model_df.get("age", pd.Series(np.nan, index=model_df.index)))
model_df["edu_num"] = to_ordered_numeric(model_df.get("education", pd.Series(np.nan, index=model_df.index)))


CAT_DEMOS = [c for c in ["gender","region"] if c in model_df.columns]
NUM_DEMOS = []
if "enthusiast" in model_df.columns and model_df["enthusiast"].dropna().dtype.kind in "biufc":
    NUM_DEMOS.append("enthusiast")



for t in traits_ord:
    model_df[f"{t}_c"] = pd.to_numeric(model_df[t], errors="coerce") - 3


for v in ["age_num","edu_num"] + NUM_DEMOS:
    if v in model_df.columns:
        mv = pd.to_numeric(model_df[v], errors="coerce")
        model_df[f"{v}_c"] = mv - mv.mean()

traits_c = [f"{t}_c" for t in traits_ord]
num_covs_c = [v for v in ["age_num_c","edu_num_c"] if v in model_df.columns] + [f"{v}_c" for v in NUM_DEMOS if f"{v}_c" in model_df.columns]


style_term = "C(explanation_type_norm, Treatment('featurebased'))"

# Model 1: style only
m1_terms = [style_term]

# Model 2: style + centered traits + centered covariates + categorical demos
m2_terms = [style_term] + traits_c + num_covs_c + [f"C({c})" for c in CAT_DEMOS]

# Model 3: Model 2 + style×trait interactions (traits are centered)
m3_interactions = [f"{style_term}:{t}" for t in traits_c]
m3_terms = m2_terms + m3_interactions

def run_block(dv: str, terms: list, label: str):
    formula = f"{dv} ~ " + " + ".join(terms)
    res = fit_ols(formula, model_df)
    print("\n" + "="*88)
    print(f"{label}  |  DV = {dv}")
    print("="*88)
    print(_format_ols_table(res, decimals=3).to_string())
    print("\nR^2: {:.3f}   Adj. R^2: {:.3f}   N: {}".format(res.rsquared, res.rsquared_adj, int(res.nobs)))
    return res


ols_results = {}
for dv in ["y_quality","y_taste","y_listen"]:
    r1 = run_block(dv, m1_terms, label="BASELINE (style only)")
    r2 = run_block(dv, m2_terms, label="Model 2 (style + centered traits + covariates)")
    r3 = run_block(dv, m3_terms, label="Model 3 (style×traits + covariates)")
    ols_results[dv] = (r1, r2, r3)


def print_sig_only(res, title, alpha=0.05):
    tbl = _format_ols_table(res)
    sig = tbl[tbl["p>|t|"] < alpha]
    if sig.empty:
        print(f"\n{title}: no terms with p<{alpha}")
    else:
        print(f"\n{title}: significant terms (p<{alpha})")
        print(sig.sort_values("p>|t|")[["coef","p>|t|"]].to_string())

for dv in ["y_quality","y_taste","y_listen"]:
    print_sig_only(ols_results[dv][2], f"Model 3 significant terms for {dv}")


def fit_ordered_logit(dv: str):
    rhs_cols = ["explanation_type_norm"] + CAT_DEMOS + traits_c + num_covs_c
    rhs_cols = [c for c in rhs_cols if c in model_df.columns]
    subset = model_df[[dv] + rhs_cols].dropna()

    X = pd.get_dummies(subset[["explanation_type_norm"] + CAT_DEMOS], drop_first=True)
    num_cols = [c for c in traits_c + num_covs_c if c in subset.columns]
    if num_cols:
        X = pd.concat([X, subset[num_cols].apply(pd.to_numeric, errors="coerce")], axis=1)

    X = X.apply(pd.to_numeric, errors="coerce").astype(float)
    y = pd.to_numeric(subset[dv], errors="coerce").round().clip(1,5).astype(int)

    mod = OrderedModel(y, X, distr="logit")
    res = mod.fit(method="bfgs", disp=False)

    # Null model for McFadden pseudo-R^2
    X0 = np.ones((len(y), 1))
    mod0 = OrderedModel(y, X0, distr="logit")
    res0 = mod0.fit(method="bfgs", disp=False)

    llf_full, llf_null = float(res.llf), float(res0.llf)
    k = X.shape[1]
    mcfadden = 1.0 - (llf_full / llf_null)
    mcfadden_adj = 1.0 - ((llf_full - k) / llf_null)

    print("\n" + "-"*88)
    print(f"Ordered logit robustness | DV = {dv}")
    print("-"*88)
    kfeat = X.shape[1]
    params = pd.Series(res.params[:kfeat], index=X.columns, name="coef")
    zvals  = params / pd.Series(res.bse[:kfeat], index=X.columns)
    pvals  = pd.Series(res.pvalues[:kfeat], index=X.columns, name="p>|z|")
    coef_tbl = pd.concat([params, zvals.rename("z"), pvals], axis=1)
    coef_tbl["odds_ratio"] = np.exp(coef_tbl["coef"])
    print(coef_tbl[["coef","z","p>|z|","odds_ratio"]].round(3).to_string())
    print("\nPseudo-R^2 (McFadden): {:.3f}   Adjusted McFadden: {:.3f}   N: {}".format(mcfadden, mcfadden_adj, len(y)))
    return res, (mcfadden, mcfadden_adj)

def style_contrast_at_means(res, style_label="neuroticism"):

    params = res.params
    index = list(params.index)


    means_unc = model_df[traits_ord].mean()
    means_c = means_unc - 3

    def idx(name):
        return index.index(name) if name in index else None

    L = np.zeros(len(params))
    main_name = f"C(explanation_type_norm, Treatment('featurebased'))[T.{style_label}]"
    i = idx(main_name)
    if i is None:
        raise ValueError(f"Style main effect not found: {main_name}")
    L[i] = 1.0


    for t in traits_ord:
        term = f"C(explanation_type_norm, Treatment('featurebased'))[T.{style_label}]:{t}_c"
        j = idx(term)
        if j is not None:
            L[j] = means_c[t]

    test = res.t_test(L)
    return test
# Out:
# ========================================================================================
# BASELINE (style only)  |  DV = y_quality
# ========================================================================================
#                                                                            coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                 4.674  79.890  0.000   4.560    4.789
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]     -0.036  -0.406  0.685  -0.213    0.140
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness] -0.320  -2.294  0.022  -0.593   -0.047
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]      -0.297  -2.535  0.011  -0.527   -0.067
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]        0.020   0.236  0.814  -0.146    0.186
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]          -0.049  -0.490  0.624  -0.247    0.148
#
# R^2: 0.046   Adj. R^2: 0.032   N: 348
#
# ========================================================================================
# Model 2 (style + centered traits + covariates)  |  DV = y_quality
# ========================================================================================
#                                                                            coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                 4.516  21.476  0.000   4.104    4.928
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]     -0.039  -0.455  0.649  -0.205    0.128
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness] -0.379  -2.779  0.005  -0.646   -0.112
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]      -0.280  -2.392  0.017  -0.509   -0.051
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]        0.028   0.333  0.739  -0.139    0.196
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]          -0.056  -0.554  0.580  -0.253    0.141
# C(gender)[T.2]                                                           -0.052  -0.522  0.601  -0.248    0.143
# C(gender)[T.3]                                                           -0.231  -0.746  0.455  -0.838    0.376
# C(region)[T.2]                                                           -0.103  -0.537  0.591  -0.478    0.272
# C(region)[T.3]                                                            0.086   0.423  0.673  -0.314    0.486
# C(region)[T.4]                                                            0.042   0.232  0.817  -0.312    0.395
# C(region)[T.5]                                                           -0.082  -0.430  0.667  -0.455    0.291
# openness_c                                                                0.004   0.078  0.938  -0.091    0.099
# conscientiousness_c                                                      -0.034  -0.552  0.581  -0.157    0.088
# extroversion_c                                                           -0.010  -0.208  0.835  -0.104    0.084
# agreeableness_c                                                           0.155   2.481  0.013   0.032    0.277
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:neuroticism_c             0.145   0.849  0.396  -0.190    0.480
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:neuroticism_c             -0.014  -0.126  0.899  -0.238    0.210
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:neuroticism_c                 0.162   1.224  0.221  -0.097    0.421
# age_num_c                                                                                    -0.035  -1.146  0.252  -0.095    0.025
# edu_num_c                                                                                     0.032   1.437  0.151  -0.012    0.076
# enthusiast_c                                                                                  0.127   3.058  0.002   0.046    0.209
#
# R^2: 0.227   Adj. R^2: 0.115   N: 348
#
# ========================================================================================
# BASELINE (style only)  |  DV = y_taste
# ========================================================================================
#                                                                            coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                 4.547  69.268  0.000   4.418    4.675
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]      0.022   0.242  0.809  -0.159    0.204
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness] -0.321  -2.357  0.018  -0.587   -0.054
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]      -0.263  -2.120  0.034  -0.507   -0.020
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]        0.078   0.856  0.392  -0.101    0.258
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]          -0.130  -1.038  0.299  -0.375    0.115
#
# R^2: 0.046   Adj. R^2: 0.032   N: 348
#
# ========================================================================================
# Model 2 (style + centered traits + covariates)  |  DV = y_taste
# ========================================================================================
#                                                                            coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                 4.138  17.492  0.000   3.674    4.602
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]      0.020   0.231  0.817  -0.147    0.187
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness] -0.412  -3.197  0.001  -0.665   -0.160
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]      -0.227  -1.803  0.071  -0.474    0.020
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]        0.099   1.044  0.297  -0.087    0.285
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]          -0.124  -0.992  0.321  -0.368    0.121
# C(gender)[T.2]                                                            0.077   0.710  0.478  -0.135    0.289
# C(gender)[T.3]                                                           -0.114  -0.386  0.700  -0.696    0.467
# C(region)[T.2]                                                            0.052   0.229  0.819  -0.395    0.500
# C(region)[T.3]                                                            0.211   0.935  0.350  -0.231    0.652
# C(region)[T.4]                                                            0.148   0.719  0.472  -0.255    0.551
# C(region)[T.5]                                                            0.067   0.322  0.748  -0.343    0.478
# openness_c                                                               -0.058  -1.061  0.289  -0.166    0.049
# conscientiousness_c                                                      -0.079  -0.973  0.330  -0.240    0.081
# extroversion_c                                                           -0.029  -0.738  0.460  -0.106    0.048
# agreeableness_c                                                           0.304   3.882  0.000   0.151    0.458
# neuroticism_c                                                             0.030   0.705  0.481  -0.053    0.113
# age_num_c                                                                -0.070  -2.100  0.036  -0.136   -0.005
# edu_num_c                                                                 0.047   1.785  0.074  -0.005    0.098
# enthusiast_c                                                              0.097   1.880  0.060  -0.004    0.198
#
# R^2: 0.136   Adj. R^2: 0.086   N: 348
#
# ========================================================================================
# Model 3 (style×traits + covariates)  |  DV = y_taste
# ========================================================================================
#                                                                                                coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                                     4.327  17.953  0.000   3.855    4.800
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]                         -0.290  -1.209  0.227  -0.759    0.180
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]                     -0.703  -1.766  0.077  -1.483    0.077
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]                          -0.082  -0.284  0.777  -0.652    0.487
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]                            0.501   1.770  0.077  -0.054    1.056
# C(explanation_type_norm, Treatment('featurebased'))[T.openness
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]          -0.002  -0.013  0.989  -0.287    0.283
#
# R^2: 0.031   Adj. R^2: 0.017   N: 348
#
# ========================================================================================
# Model 2 (style + centered traits + covariates)  |  DV = y_listen
# ========================================================================================
#                                                                            coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                 4.100  12.202  0.000   3.441    4.758
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]      0.071   0.636  0.525  -0.148    0.290
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness] -0.191  -1.262  0.207  -0.487    0.105
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]      -0.124  -0.840  0.401  -0.413    0.165
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]        0.283   2.399  0.016   0.052    0.515
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]           0.015   0.098  0.922  -0.279    0.308
# C(gender)[T.2]                                                            0.033   0.245  0.807  -0.229    0.294
# C(gender)[T.3]                                                           -0.376  -0.652  0.514  -1.505    0.753
# C(region)[T.2]                                                            0.084   0.258  0.796  -0.556    0.724
# C(region)[T.3]                                                            0.321   0.987  0.323  -0.316    0.958
# C(region)[T.4]                                                            0.235   0.753  0.451  -0.377    0.848
# C(region)[T.5]                                                           -0.013  -0.042  0.966  -0.638    0.611
# openness_c                                                               -0.103  -1.527  0.127  -0.236    0.029
# conscientiousness_c                                                      -0.019  -0.195  0.846  -0.208    0.171
# extroversion_c                                                            0.026   0.475  0.635  -0.081    0.134
# agreeableness_c                                                           0.199   2.109  0.035   0.014    0.383
# neuroticism_c                                                             0.007   0.147  0.883  -0.092    0.107
# age_num_c                                                                -0.081  -1.813  0.070  -0.169    0.007
# edu_num_c                                                                 0.045   1.529  0.126  -0.013    0.102
# enthusiast_c                                                              0.108   1.885  0.059  -0.004    0.221
#
# R^2: 0.109   Adj. R^2: 0.057   N: 348
#
# ========================================================================================
# Model 3 (style×traits + covariates)  |  DV = y_listen
# ========================================================================================
#                                                                                                coef       t  p>|t|  ci_low  ci_high
# Intercept                                                                                     4.343  12.075  0.000   3.638    5.048
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]                         -0.519  -1.629  0.103  -1.143    0.105
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]                     -0.463  -0.868  0.385  -1.509    0.582
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]                          -0.010  -0.029  0.977  -0.726    0.705
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]                            0.410   1.114  0.265  -0.311    1.132
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]                              -0.223  -0.544  0.587  -1.026    0.580
# C(gender)[T.2]                                                                               -0.008  -0.057  0.955  -0.283    0.267
# C(gender)[T.3]                                                                               -0.433  -0.726  0.468  -1.602    0.736
# C(region)[T.2]                                                                               -0.060  -0.207  0.836  -0.627    0.507
# C(region)[T.3]                                                                                0.159   0.563  0.574  -0.395    0.714
# C(region)[T.4]                                                                                0.085   0.313  0.754  -0.448    0.619
# C(region)[T.5]                                                                               -0.156  -0.575  0.566  -0.690    0.377
# openness_c                                                                                   -0.155  -1.223  0.221  -0.402    0.093
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:openness_c               0.316   1.874  0.061  -0.014    0.647
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:openness_c          -0.217  -1.144  0.253  -0.589    0.155
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:openness_c               -0.073  -0.391  0.696  -0.440    0.294
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:openness_c                 0.195   1.055  0.291  -0.167    0.556
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:openness_c                    0.249   0.981  0.326  -0.248    0.746
# conscientiousness_c                                                                          -0.218  -1.063  0.288  -0.619    0.184
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:conscientiousness_c      0.261   0.890  0.373  -0.313    0.834
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:conscientiousness_c  0.012   0.043  0.966  -0.531    0.555
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:conscientiousness_c       0.477   1.354  0.176  -0.214    1.167
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:conscientiousness_c        0.098   0.384  0.701  -0.402    0.598
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:conscientiousness_c           0.343   0.941  0.347  -0.372    1.058
# extroversion_c                                                                                0.078   0.614  0.539  -0.171    0.327
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:extroversion_c          -0.120  -0.821  0.411  -0.407    0.166
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:extroversion_c       0.045   0.282  0.778  -0.266    0.355
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:extroversion_c            0.330   1.382  0.167  -0.138    0.799
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:extroversion_c            -0.166  -1.141  0.254  -0.452    0.119
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:extroversion_c               -0.393  -2.241  0.025  -0.737   -0.049
# agreeableness_c                                                                               0.322   1.938  0.053  -0.004    0.647
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:agreeableness_c          0.029   0.120  0.904  -0.443    0.501
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:agreeableness_c      0.238   0.935  0.350  -0.261    0.736
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:agreeableness_c          -0.459  -1.611  0.107  -1.016    0.099
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:agreeableness_c           -0.286  -1.303  0.193  -0.716    0.144
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:agreeableness_c              -0.313  -0.870  0.384  -1.018    0.392
# neuroticism_c                                                                                -0.253  -1.939  0.053  -0.509    0.003
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:neuroticism_c            0.308   2.129  0.033   0.024    0.592
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:neuroticism_c        0.587   3.877  0.000   0.290    0.883
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:neuroticism_c             0.391   2.038  0.042   0.015    0.766
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:neuroticism_c              0.130   0.837  0.403  -0.174    0.433
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:neuroticism_c                 0.452   2.486  0.013   0.096    0.808
# age_num_c                                                                                    -0.058  -1.336  0.182  -0.142    0.027
# edu_num_c                                                                                     0.045   1.593  0.111  -0.010    0.100
# enthusiast_c                                                                                  0.086   1.792  0.073  -0.008    0.181
#
# R^2: 0.262   Adj. R^2: 0.155   N: 348
#
# Model 3 significant terms for y_quality: significant terms (p<0.05)
#                                                                                       coef  p>|t|
# Intercept                                                                            4.558  0.000
# enthusiast_c                                                                         0.127  0.002
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:extroversion_c -0.289  0.014
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]                -0.528  0.035
#
# Model 3 significant terms for y_taste: significant terms (p<0.05)
#                                                                                           coef  p>|t|
# Intercept                                                                                4.327  0.000
# agreeableness_c                                                                          0.467  0.000
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:neuroticism_c   0.424  0.002
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:neuroticism_c            0.418  0.006
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:conscientiousness_c  0.804  0.008
# conscientiousness_c                                                                     -0.328  0.008
# C(explanation_type_norm, Treatment('featurebased'))[T.neuroticism]:agreeableness_c      -0.347  0.042
#
# Model 3 significant terms for y_listen: significant terms (p<0.05)
#                                                                                          coef  p>|t|
# Intercept                                                                               4.343  0.000
# C(explanation_type_norm, Treatment('featurebased'))[T.conscientiousness]:neuroticism_c  0.587  0.000
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:neuroticism_c           0.452  0.013
# C(explanation_type_norm, Treatment('featurebased'))[T.openness]:extroversion_c         -0.393  0.025
# C(explanation_type_norm, Treatment('featurebased'))[T.agreeableness]:neuroticism_c      0.308  0.033
# C(explanation_type_norm, Treatment('featurebased'))[T.extroversion]:neuroticism_c       0.391  0.042
